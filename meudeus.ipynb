# %%
import pandas as pd 
import numpy as np

# %%
for coluna in ['area', 'populacao', 'densidade', 'idh']:
    print(coluna)
    print(round(estados[coluna].describe(), 2))
estados['area'].plot()
# Out:
# area
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 for coluna in ['area', 'populacao', 'densidade', 'idh']:
#       2     print(coluna)
# ----> 3     print(round(estados[coluna].describe(), 2))
#       4 estados['area'].plot()
#
# NameError: name 'estados' is not defined

# %%
import pandas as pd
import numpy as np
estados = pd.read_csv('brasil_estados.csv')
estados
estados.info()
round(estados['area'].describe(), 2)
for coluna in ['area', 'populacao', 'densidade', 'idh']:
    print(coluna)
    print(round(estados[coluna].describe(), 2))
estados['area'].plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   27 non-null     int64
#  1   uf           27 non-null     object
#  2   codigo       27 non-null     int64
#  3   area         27 non-null     float64
#  4   populacao    27 non-null     int64
#  5   densidade    27 non-null     float64
#  6   matricula    27 non-null     int64
#  7   idh          27 non-null     float64
#  8   receitas     27 non-null     float64
#  9   despesas     27 non-null     float64
#  10  rendimento   27 non-null     int64
#  11  veiculos     27 non-null     int64
#  12  regiao_nome  27 non-null     object
#  13  sigla        27 non-null     object
#  14  estado       27 non-null     object
#  15  latitude     27 non-null     float64
#  16  longitude    27 non-null     float64
# dtypes: float64(7), int64(6), object(4)
# memory usage: 3.7+ KB
# area
# count         27.00
# mean      315196.14
# std       375119.73
# min         5760.78
# 25%        76098.96
# 50%       223644.53
# 75%       334922.76
# max      1559167.89
# Name: area, dtype: float64
# populacao
# count          27.00
# mean      7842803.41
# std       9316952.10
# min        631181.00
# 25%       2932271.50
# 50%       4064052.00
# 75%       9401862.00
# max      46289333.00
# Name: populacao, dtype: float64
# densidade
# count     27.00
# mean      68.04
# std      105.91
# min        2.01
# 25%        6.32
# 50%       33.41
# 75%       71.47
# max      444.66
# Name: densidade, dtype: float64
# idh
# count    27.00
# mean      0.70
# std       0.05
# min       0.63
# 25%       0.66
# 50%       0.70
# 75%       0.74
# max       0.82
# Name: idh, dtype: float64
# <Axes: >

# %%
import seaborn as sns

# %%
sns.catplot(
     data=estados,
     x='sigla',
     y='populacao',
     kind='bar'
     )

# %%
sns.boxplot(
    data=estados,  
    y='area'
    )
# Out:
# <Axes: ylabel='area'>

# %%
out_max = estados['area'].mean() + (3 * estados['area'].std())
print(out_max)
# Out:
# 1440555.3438102247

# %%
out_max_mad = estados['area'].quantile(0.75) + \
   ((estados['area'].quantile(0.75) - \
     estados['area'].quantile(0.25)) * 1.5)
print(out_max_mad)
# Out:
# 723158.44425

# %%
limite_inferior = estado['area'].mean() - (
    1.96 * estados['area'].std() / np.sqrt(len(estados['area']))
)
print(limite_inferior)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 limite_inferior = estado['area'].mean() - (
#       2     1.96 * estados['area'].std() / np.sqrt(len(estados['area']))
#       3 )
#       4 print(limite_inferior)
#
# NameError: name 'estado' is not defined

# %%
limite_superior = estados['area'].mean() + (
    1.96 * estados['area'].std() / np.sqrt(len(estados['area']))
)
print(limite_superior)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 limite_superior = estados['area'].mean() + (
#       2     1.96 * estados['area'].std() / np.sqrt(len(estados['area']))
#       3 )
#       4 print(limite_superior)
#
# NameError: name 'estados' is not defined
